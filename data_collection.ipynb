# %% [markdown]
# # Data Collection
#
# #### We collect tweets regarding the **META** (ticker:`META`) company using StockTwits API.

# %% [markdown]
# ### Seup the environement

# %%
#!pip install "pymongo[srv]"==3.11
#!pip install pymongo --upgrade
#!pip install openai

# %% [markdown]
# ### Import libs

# %%
#### COMMON ####
import pandas as pd
import numpy as np

import json
import requests
from datetime import datetime

### MONGO DB ####
from pymongo.mongo_client import MongoClient

### Import utils function ###
from utils import test_connection_db, collect_tweets, insert_tweets, retrieve_from_mongodb, URI, DB_NAME

# %% [markdown]
# ### STEP 1: Load `META` tweets from StockTwits

# %%
df_meta_tweets = collect_tweets(ticker="META", nb_url=10)
# Out:
# STARTING TO COLLECT TWEET META...
#
#
# COLLECTNG FROM:...
# 1: https://api.stocktwits.com/api/2/streams/symbol/META.json
# COLLECTNG FROM:...
# 2: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565498474
# COLLECTNG FROM:...
# 3: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565476183
# COLLECTNG FROM:...
# 4: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565459532
# COLLECTNG FROM:...
# 5: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565450575
# COLLECTNG FROM:...
# 6: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565441413
# COLLECTNG FROM:...
# 7: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565428221
# COLLECTNG FROM:...
# 8: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565409077
# COLLECTNG FROM:...
# 9: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565385558
# COLLECTNG FROM:...
# 10: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565372464
#
# 116 TWEETS ARE SUCCESFULLY COLLECTED FROM THE TICKERMETA

# %%
df_meta_tweets
# Out:
#                      date                                            content  \
# 0    2024-03-12T19:46:15Z  $PSTG $NTAP $META that’s a big hit to PSTG pro...
# 3    2024-03-12T19:37:31Z  $ATNF looks primed for a big Squeeze 🔥  \n \nW...
# 4    2024-03-12T19:36:29Z                   $META it’s over. Thx for playing
# 7    2024-03-12T19:30:43Z                         $META $600 on tok ban tomm
# 9    2024-03-12T19:28:36Z  $SPY $NVDA $META $ORCL Trump was an idiot to t...
# ..                    ...                                                ...
# 286  2024-03-11T23:41:49Z  $META *TIKTOK A US SECURITY THREAT, SAYS TRUMP...
# 287  2024-03-11T23:40:45Z  $META I don’t care what political affiliation ...
# 289  2024-03-11T23:36:55Z  $META don’t forget how Trump makes fun of hand...
# 296  2024-03-11T22:31:23Z  $META Enemy of the People! \nhttps://www.youtu...
# 299  2024-03-11T22:27:54Z  $META Trump will absolutely abuse his power as...
#
#     true_sentiment
# 0          bearish
# 3          bullish
# 4          bearish
# 7          bullish
# 9          bullish
# ..             ...
# 286        bullish
# 287        bullish
# 289        bullish
# 296        bearish
# 299        bullish
#
# [116 rows x 3 columns]

# %% [markdown]
# #### NOTE:
#
# * The sentiment given by StockTwits will be the label (ground truth) of our data

# %% [markdown]
# ### Store the tweets collection into the DB

# %% [markdown]
# ##### Test the connection with the MongoDB cluster

# %%
test_connection_db(URI)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
insert_tweets(df_meta_tweets, uri=URI, db_name=DB_NAME, collection_name="META")
# Out:
# STARTING TO CLEAN DATA...
# tweets_db.META COLLECTION IS SUCCESSFULLY CLEANED
#
#
# STARTING TO INSERT DATA...
# row: 0 inserted
# row: 3 inserted
# row: 4 inserted
# row: 7 inserted
# row: 9 inserted
# row: 13 inserted
# row: 17 inserted
# row: 29 inserted
# row: 30 inserted
# row: 32 inserted
# row: 33 inserted
# row: 34 inserted
# row: 36 inserted
# row: 37 inserted
# row: 38 inserted
# row: 40 inserted
# row: 41 inserted
# row: 42 inserted
# row: 49 inserted
# row: 51 inserted
# row: 52 inserted
# row: 53 inserted
# row: 55 inserted
# row: 58 inserted
# row: 60 inserted
# row: 62 inserted
# row: 64 inserted
# row: 66 inserted
# row: 69 inserted
# row: 72 inserted
# row: 74 inserted
# row: 77 inserted
# row: 80 inserted
# row: 87 inserted
# row: 91 inserted
# row: 93 inserted
# row: 94 inserted
# row: 98 inserted
# row: 99 inserted
# row: 101 inserted
# row: 105 inserted
# row: 107 inserted
# row: 110 inserted
# row: 113 inserted
# row: 114 inserted
# row: 116 inserted
# row: 118 inserted
# row: 119 inserted
# row: 120 inserted
# row: 121 inserted
# row: 125 inserted
# row: 126 inserted
# row: 127 inserted
# row: 129 inserted
# row: 133 inserted
# row: 136 inserted
# row: 137 inserted
# row: 139 inserted
# row: 142 inserted
# row: 151 inserted
# row: 153 inserted
# row: 154 inserted
# row: 156 inserted
# row: 157 inserted
# row: 161 inserted
# row: 163 inserted
# row: 164 inserted
# row: 169 inserted
# row: 170 inserted
# row: 171 inserted
# row: 172 inserted
# row: 175 inserted
# row: 177 inserted
# row: 184 inserted
# row: 185 inserted
# row: 186 inserted
# row: 188 inserted
# row: 190 inserted
# row: 192 inserted
# row: 194 inserted
# row: 197 inserted
# row: 199 inserted
# row: 200 inserted
# row: 201 inserted
# row: 202 inserted
# row: 203 inserted
# row: 204 inserted
# row: 205 inserted
# row: 210 inserted
# row: 213 inserted
# row: 215 inserted
# row: 219 inserted
# row: 224 inserted
# row: 225 inserted
# row: 233 inserted
# row: 234 inserted
# row: 236 inserted
# row: 238 inserted
# row: 242 inserted
# row: 250 inserted
# row: 260 inserted
# row: 262 inserted
# row: 264 inserted
# row: 266 inserted
# row: 267 inserted
# row: 274 inserted
# row: 275 inserted
# row: 277 inserted
# row: 281 inserted
# row: 282 inserted
# row: 285 inserted
# row: 286 inserted
# row: 287 inserted
# row: 289 inserted
# row: 296 inserted
# row: 299 inserted
#
#
#  116 ROWS INSERTED SUCCESSFULLY INTO tweets_db.META

# %% [markdown]
# ### Extract data from the MongoDB database

# %%
# Retrieve data from MongoDB
data_from_mongodb = retrieve_from_mongodb(uri=URI, db_name=DB_NAME, collection_name="META")

# Create DataFrame from retrieved data
df_meta_tweets_ = pd.DataFrame(data_from_mongodb)

df_meta_tweets_
# Out:
#                           _id                  date  \
# 0    65f0b1f3785c5752056d15f1  2024-03-12T19:46:15Z
# 1    65f0b1f4785c5752056d15f3  2024-03-12T19:37:31Z
# 2    65f0b1f4785c5752056d15f5  2024-03-12T19:36:29Z
# 3    65f0b1f5785c5752056d15f7  2024-03-12T19:30:43Z
# 4    65f0b1f6785c5752056d15f9  2024-03-12T19:28:36Z
# ..                        ...                   ...
# 111  65f0b239785c5752056d16cf  2024-03-11T23:41:49Z
# 112  65f0b23a785c5752056d16d1  2024-03-11T23:40:45Z
# 113  65f0b23b785c5752056d16d3  2024-03-11T23:36:55Z
# 114  65f0b23b785c5752056d16d5  2024-03-11T22:31:23Z
# 115  65f0b23c785c5752056d16d7  2024-03-11T22:27:54Z
#
#                                                content true_sentiment
# 0    $PSTG $NTAP $META that’s a big hit to PSTG pro...        bearish
# 1    $ATNF looks primed for a big Squeeze 🔥  \n \nW...        bullish
# 2                     $META it’s over. Thx for playing        bearish
# 3                           $META $600 on tok ban tomm        bullish
# 4    $SPY $NVDA $META $ORCL Trump was an idiot to t...        bullish
# ..                                                 ...            ...
# 111  $META *TIKTOK A US SECURITY THREAT, SAYS TRUMP...        bullish
# 112  $META I don’t care what political affiliation ...        bullish
# 113  $META don’t forget how Trump makes fun of hand...        bullish
# 114  $META Enemy of the People! \nhttps://www.youtu...        bearish
# 115  $META Trump will absolutely abuse his power as...        bullish
#
# [116 rows x 4 columns]
