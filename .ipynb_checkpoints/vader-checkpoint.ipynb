# %% [markdown]
# # Sentiment Analysis of Stock Twits with VADER

# %% [markdown]
# ### Import libs

# %%
#### NLP LIBS ###
import nltk
import numpy as np
import pandas as pd
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

### Import utils function ###
from utils import get_tweets_from_db, eval_model, URI, DB_NAME
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\humic\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Get Tweets from MongoDB database (`db_tweets.META`)

# %%
# Retrieve data from MongoDB
data_from_mongodb = get_tweets_from_db(uri=URI, db_name=DB_NAME, collection_name="META")

# Create DataFrame from retrieved data
df_meta_tweets = pd.DataFrame(data_from_mongodb)

df_meta_tweets
# Out:
#                           _id                  date  \
# 0    65f0b1f3785c5752056d15f1  2024-03-12T19:46:15Z
# 1    65f0b1f4785c5752056d15f3  2024-03-12T19:37:31Z
# 2    65f0b1f4785c5752056d15f5  2024-03-12T19:36:29Z
# 3    65f0b1f5785c5752056d15f7  2024-03-12T19:30:43Z
# 4    65f0b1f6785c5752056d15f9  2024-03-12T19:28:36Z
# ..                        ...                   ...
# 111  65f0b239785c5752056d16cf  2024-03-11T23:41:49Z
# 112  65f0b23a785c5752056d16d1  2024-03-11T23:40:45Z
# 113  65f0b23b785c5752056d16d3  2024-03-11T23:36:55Z
# 114  65f0b23b785c5752056d16d5  2024-03-11T22:31:23Z
# 115  65f0b23c785c5752056d16d7  2024-03-11T22:27:54Z
#
#                                                content true_sentiment
# 0    $PSTG $NTAP $META that’s a big hit to PSTG pro...        bearish
# 1    $ATNF looks primed for a big Squeeze 🔥  \n \nW...        bullish
# 2                     $META it’s over. Thx for playing        bearish
# 3                           $META $600 on tok ban tomm        bullish
# 4    $SPY $NVDA $META $ORCL Trump was an idiot to t...        bullish
# ..                                                 ...            ...
# 111  $META *TIKTOK A US SECURITY THREAT, SAYS TRUMP...        bullish
# 112  $META I don’t care what political affiliation ...        bullish
# 113  $META don’t forget how Trump makes fun of hand...        bullish
# 114  $META Enemy of the People! \nhttps://www.youtu...        bearish
# 115  $META Trump will absolutely abuse his power as...        bullish
#
# [116 rows x 4 columns]

# %% [markdown]
# ## Compute sentiment score with VADER algorithm

# %%
sid = SentimentIntensityAnalyzer()

def compute_sentiment_score_VADER(tweet):
    scores = sid.polarity_scores(tweet)
    sentiment_dict = {'tweet':tweet, 'bullish_score': scores['pos'], 'bearish_score': scores['neg'], 'neutral_score': scores['neu'], 'compound_score': scores['compound']}
    return sentiment_dict

list_dict = list()

for tweet in df_meta_tweets["content"]:
    sentiment = compute_sentiment_score_VADER(tweet)
    list_dict.append(sentiment) 

df_sentiment = pd.DataFrame(list_dict)
df_sentiment
# Out:
#                                                  tweet  bullish_score  \
# 0    $PSTG $NTAP $META that’s a big hit to PSTG pro...          0.000
# 1    $ATNF looks primed for a big Squeeze 🔥  \n \nW...          0.000
# 2                     $META it’s over. Thx for playing          0.518
# 3                           $META $600 on tok ban tomm          0.000
# 4    $SPY $NVDA $META $ORCL Trump was an idiot to t...          0.000
# ..                                                 ...            ...
# 111  $META *TIKTOK A US SECURITY THREAT, SAYS TRUMP...          0.152
# 112  $META I don’t care what political affiliation ...          0.127
# 113  $META don’t forget how Trump makes fun of hand...          0.159
# 114  $META Enemy of the People! \nhttps://www.youtu...          0.000
# 115  $META Trump will absolutely abuse his power as...          0.000
#
#      bearish_score  neutral_score  compound_score
# 0            0.000          1.000          0.0000
# 1            0.000          1.000          0.0000
# 2            0.000          0.482          0.5106
# 3            0.419          0.581         -0.5574
# 4            0.218          0.782         -0.7717
# ..             ...            ...             ...
# 111          0.215          0.633         -0.2500
# 112          0.366          0.507         -0.9224
# 113          0.264          0.577         -0.2960
# 114          0.431          0.569         -0.5848
# 115          0.230          0.770         -0.6989
#
# [116 rows x 5 columns]

# %% [markdown]
# #### Post-Processing: Compute the predicted label
# * `bullish`
# * `bearish`

# %%
df_meta_tweets["predicted_sentiment"] = df_sentiment.apply(lambda row: 'bearish' if row['compound_score'] <= -0.5 else 'bullish', axis=1)
df_meta_tweets
# Out:
#                           _id                  date  \
# 0    65f0b1f3785c5752056d15f1  2024-03-12T19:46:15Z
# 1    65f0b1f4785c5752056d15f3  2024-03-12T19:37:31Z
# 2    65f0b1f4785c5752056d15f5  2024-03-12T19:36:29Z
# 3    65f0b1f5785c5752056d15f7  2024-03-12T19:30:43Z
# 4    65f0b1f6785c5752056d15f9  2024-03-12T19:28:36Z
# ..                        ...                   ...
# 111  65f0b239785c5752056d16cf  2024-03-11T23:41:49Z
# 112  65f0b23a785c5752056d16d1  2024-03-11T23:40:45Z
# 113  65f0b23b785c5752056d16d3  2024-03-11T23:36:55Z
# 114  65f0b23b785c5752056d16d5  2024-03-11T22:31:23Z
# 115  65f0b23c785c5752056d16d7  2024-03-11T22:27:54Z
#
#                                                content true_sentiment  \
# 0    $PSTG $NTAP $META that’s a big hit to PSTG pro...        bearish
# 1    $ATNF looks primed for a big Squeeze 🔥  \n \nW...        bullish
# 2                     $META it’s over. Thx for playing        bearish
# 3                           $META $600 on tok ban tomm        bullish
# 4    $SPY $NVDA $META $ORCL Trump was an idiot to t...        bullish
# ..                                                 ...            ...
# 111  $META *TIKTOK A US SECURITY THREAT, SAYS TRUMP...        bullish
# 112  $META I don’t care what political affiliation ...        bullish
# 113  $META don’t forget how Trump makes fun of hand...        bullish
# 114  $META Enemy of the People! \nhttps://www.youtu...        bearish
# 115  $META Trump will absolutely abuse his power as...        bullish
#
#     predicted_sentiment
# 0               bullish
# 1               bullish
# 2               bullish
# 3               bearish
# 4               bearish
# ..                  ...
# 111             bullish
# 112             bearish
# 113             bullish
# 114             bearish
# 115             bearish
#
# [116 rows x 5 columns]

# %% [markdown]
# ### Model Evaluation
#
# To evaluate the model performance prediction we compute the confusion matrix and the classification report

# %%
eval_model(df_meta_tweets["true_sentiment"], df_meta_tweets["predicted_sentiment"])
# Out:
# ######## Classification Report ########
#
#               precision    recall  f1-score   support
#
#      bearish       0.43      0.21      0.28        43
#      bullish       0.64      0.84      0.73        73
#
#     accuracy                           0.60       116
#    macro avg       0.54      0.52      0.50       116
# weighted avg       0.56      0.60      0.56       116
#
# ######## Accuracy Score ########
# 0.6

# %% [markdown]
# #### Store the predicted sentiment into a new MongoDB Collection

# %%
## TO DO
