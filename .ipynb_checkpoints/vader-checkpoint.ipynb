# %% [markdown]
# # Sentiment Analysis of Stock Twits with VADER

# %% [markdown]
# ### Import libs

# %%
#### NLP LIBS ###
import nltk
import numpy as np
import pandas as pd
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

### Import utils function ###
from utils import get_tweets_from_db, eval_model, URI, DB_NAME
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\humic\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# ### Get Tweets from MongoDB database (`db_tweets.META`)

# %%
# Retrieve data from MongoDB
data_from_mongodb = get_tweets_from_db(uri=URI, db_name=DB_NAME, collection_name="META")

# Create DataFrame from retrieved data
df_meta_tweets = pd.DataFrame(data_from_mongodb)

df_meta_tweets
# Out:
#                           _id                  date  \
# 0    65f0bf79cdbba6c28e28124b  2024-03-12T20:39:18Z
# 1    65f0bf7acdbba6c28e28124d  2024-03-12T20:35:09Z
# 2    65f0bf7acdbba6c28e28124f  2024-03-12T19:46:15Z
# 3    65f0bf7bcdbba6c28e281251  2024-03-12T19:37:31Z
# 4    65f0bf7ccdbba6c28e281253  2024-03-12T19:36:29Z
# ..                        ...                   ...
# 107  65f0bfc2cdbba6c28e281321  2024-03-12T00:23:08Z
# 108  65f0bfc3cdbba6c28e281323  2024-03-12T00:20:07Z
# 109  65f0bfc4cdbba6c28e281325  2024-03-12T00:08:53Z
# 110  65f0bfc4cdbba6c28e281327  2024-03-11T23:49:38Z
# 111  65f0bfc5cdbba6c28e281329  2024-03-11T23:49:28Z
#
#                                                content true_sentiment
# 0    $SPY $NVDA $META $ORCL Only sad BEARS on here ...        bullish
# 1    $META 510 Tomorrow Bears Was that over the top...        bullish
# 2    $PSTG $NTAP $META that’s a big hit to PSTG pro...        bearish
# 3    $ATNF looks primed for a big Squeeze 🔥  \n \nW...        bullish
# 4                     $META it’s over. Thx for playing        bearish
# ..                                                 ...            ...
# 107          $META &quot;the enemy of the people&quot;        bearish
# 108  $META we don’t need any one to tell us who is ...        bullish
# 109  $META I see downtrend forming but the oversold...        bullish
# 110        $META so so OVERSOLD Will be UP like a yoyo        bullish
# 111  $META Trump reminds of that movie idiocracy. A...        bullish
#
# [112 rows x 4 columns]

# %% [markdown]
# ## Compute sentiment score with VADER algorithm

# %%
sid = SentimentIntensityAnalyzer()

def compute_sentiment_score_VADER(tweet):
    scores = sid.polarity_scores(tweet)
    sentiment_dict = {'tweet':tweet, 'bullish_score': scores['pos'], 'bearish_score': scores['neg'], 'neutral_score': scores['neu'], 'compound_score': scores['compound']}
    return sentiment_dict

list_dict = list()

for tweet in df_meta_tweets["content"]:
    sentiment = compute_sentiment_score_VADER(tweet)
    list_dict.append(sentiment) 

df_sentiment = pd.DataFrame(list_dict)
df_sentiment
# Out:
#                                                  tweet  bullish_score  \
# 0    $SPY $NVDA $META $ORCL Only sad BEARS on here ...          0.000
# 1    $META 510 Tomorrow Bears Was that over the top...          0.119
# 2    $PSTG $NTAP $META that’s a big hit to PSTG pro...          0.000
# 3    $ATNF looks primed for a big Squeeze 🔥  \n \nW...          0.000
# 4                     $META it’s over. Thx for playing          0.518
# ..                                                 ...            ...
# 107          $META &quot;the enemy of the people&quot;          0.000
# 108  $META we don’t need any one to tell us who is ...          0.000
# 109  $META I see downtrend forming but the oversold...          0.000
# 110        $META so so OVERSOLD Will be UP like a yoyo          0.358
# 111  $META Trump reminds of that movie idiocracy. A...          0.194
#
#      bearish_score  neutral_score  compound_score
# 0            0.148          0.852         -0.6597
# 1            0.154          0.727         -0.1361
# 2            0.000          1.000          0.0000
# 3            0.000          1.000          0.0000
# 4            0.000          0.482          0.5106
# ..             ...            ...             ...
# 107          0.412          0.588         -0.5423
# 108          0.250          0.750         -0.7906
# 109          0.000          1.000          0.0000
# 110          0.000          0.642          0.4404
# 111          0.199          0.607         -0.0869
#
# [112 rows x 5 columns]

# %% [markdown]
# #### Post-Processing: Compute the predicted label
# * `bullish`
# * `bearish`

# %%
df_meta_tweets["predicted_sentiment"] = df_sentiment.apply(lambda row: 'bearish' if row['compound_score'] <= -0.5 else 'bullish', axis=1)
df_meta_tweets
# Out:
#                           _id                  date  \
# 0    65f0bf79cdbba6c28e28124b  2024-03-12T20:39:18Z
# 1    65f0bf7acdbba6c28e28124d  2024-03-12T20:35:09Z
# 2    65f0bf7acdbba6c28e28124f  2024-03-12T19:46:15Z
# 3    65f0bf7bcdbba6c28e281251  2024-03-12T19:37:31Z
# 4    65f0bf7ccdbba6c28e281253  2024-03-12T19:36:29Z
# ..                        ...                   ...
# 107  65f0bfc2cdbba6c28e281321  2024-03-12T00:23:08Z
# 108  65f0bfc3cdbba6c28e281323  2024-03-12T00:20:07Z
# 109  65f0bfc4cdbba6c28e281325  2024-03-12T00:08:53Z
# 110  65f0bfc4cdbba6c28e281327  2024-03-11T23:49:38Z
# 111  65f0bfc5cdbba6c28e281329  2024-03-11T23:49:28Z
#
#                                                content true_sentiment  \
# 0    $SPY $NVDA $META $ORCL Only sad BEARS on here ...        bullish
# 1    $META 510 Tomorrow Bears Was that over the top...        bullish
# 2    $PSTG $NTAP $META that’s a big hit to PSTG pro...        bearish
# 3    $ATNF looks primed for a big Squeeze 🔥  \n \nW...        bullish
# 4                     $META it’s over. Thx for playing        bearish
# ..                                                 ...            ...
# 107          $META &quot;the enemy of the people&quot;        bearish
# 108  $META we don’t need any one to tell us who is ...        bullish
# 109  $META I see downtrend forming but the oversold...        bullish
# 110        $META so so OVERSOLD Will be UP like a yoyo        bullish
# 111  $META Trump reminds of that movie idiocracy. A...        bullish
#
#     predicted_sentiment
# 0               bearish
# 1               bullish
# 2               bullish
# 3               bullish
# 4               bullish
# ..                  ...
# 107             bearish
# 108             bearish
# 109             bullish
# 110             bullish
# 111             bullish
#
# [112 rows x 5 columns]

# %% [markdown]
# ### Model Evaluation
#
# To evaluate the model performance prediction we compute the confusion matrix and the classification report

# %%
eval_model(df_meta_tweets["true_sentiment"], df_meta_tweets["predicted_sentiment"])
# Out:
# ######## Classification Report ########
#
#               precision    recall  f1-score   support
#
#      bearish       0.42      0.19      0.26        42
#      bullish       0.63      0.84      0.72        70
#
#     accuracy                           0.60       112
#    macro avg       0.53      0.52      0.49       112
# weighted avg       0.55      0.60      0.55       112
#
# ######## Accuracy Score ########
# 0.6

# %% [markdown]
# #### Store the predicted sentiment into a new MongoDB Collection

# %%
## TO DO
