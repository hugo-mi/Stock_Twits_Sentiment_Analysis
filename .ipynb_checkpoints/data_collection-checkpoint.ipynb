# %% [markdown]
# # Data Collection
#
# #### We collect tweets regarding the **META** (ticker:`META`) company using StockTwits API.

# %% [markdown]
# ### Seup the environement

# %%
#!pip install "pymongo[srv]"==3.11
#!pip install pymongo --upgrade
#!pip install openai

# %% [markdown]
# ### Import libs

# %%
#### COMMON ####
import pandas as pd
import numpy as np

import json
import requests
from datetime import datetime

### MONGO DB ####
from pymongo.mongo_client import MongoClient

### Import utils function ###
from utils import test_connection_db, collect_tweets, insert_tweets, get_tweets_from_db, URI, DB_NAME

# %% [markdown]
# ### STEP 1: Load `META` tweets from StockTwits

# %%
df_meta_tweets = collect_tweets(ticker="META", nb_url=10)
# Out:
# STARTING TO COLLECT TWEET META...
#
#
# COLLECTNG FROM:...
# 1: https://api.stocktwits.com/api/2/streams/symbol/META.json
# COLLECTNG FROM:...
# 2: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565501459
# COLLECTNG FROM:...
# 3: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565490721
# COLLECTNG FROM:...
# 4: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565466496
# COLLECTNG FROM:...
# 5: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565457223
# COLLECTNG FROM:...
# 6: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565444544
# COLLECTNG FROM:...
# 7: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565434112
# COLLECTNG FROM:...
# 8: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565415066
# COLLECTNG FROM:...
# 9: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565395690
# COLLECTNG FROM:...
# 10: https://api.stocktwits.com/api/2/streams/symbol/META.json?max=565378771
#
# 112 TWEETS ARE SUCCESFULLY COLLECTED FROM THE TICKERMETA

# %%
df_meta_tweets
# Out:
#                      date                                            content  \
# 6    2024-03-12T20:39:18Z  $SPY $NVDA $META $ORCL Only sad BEARS on here ...
# 7    2024-03-12T20:35:09Z  $META 510 Tomorrow Bears Was that over the top...
# 15   2024-03-12T19:46:15Z  $PSTG $NTAP $META that’s a big hit to PSTG pro...
# 18   2024-03-12T19:37:31Z  $ATNF looks primed for a big Squeeze 🔥  \n \nW...
# 19   2024-03-12T19:36:29Z                   $META it’s over. Thx for playing
# ..                    ...                                                ...
# 289  2024-03-12T00:23:08Z          $META &quot;the enemy of the people&quot;
# 290  2024-03-12T00:20:07Z  $META we don’t need any one to tell us who is ...
# 292  2024-03-12T00:08:53Z  $META I see downtrend forming but the oversold...
# 296  2024-03-11T23:49:38Z        $META so so OVERSOLD Will be UP like a yoyo
# 297  2024-03-11T23:49:28Z  $META Trump reminds of that movie idiocracy. A...
#
#     true_sentiment
# 6          bullish
# 7          bullish
# 15         bearish
# 18         bullish
# 19         bearish
# ..             ...
# 289        bearish
# 290        bullish
# 292        bullish
# 296        bullish
# 297        bullish
#
# [112 rows x 3 columns]

# %% [markdown]
# #### NOTE:
#
# * The sentiment given by StockTwits will be the label (ground truth) of our data

# %% [markdown]
# ### Store the tweets collection into the DB

# %% [markdown]
# ##### Test the connection with the MongoDB cluster

# %%
test_connection_db(URI)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
insert_tweets(df_meta_tweets, uri=URI, db_name=DB_NAME, collection_name="META")
# Out:
# STARTING TO CLEAN DATA...
# tweets_db.META COLLECTION IS SUCCESSFULLY CLEANED
#
#
# STARTING TO INSERT DATA...
# row: 6 inserted
# row: 7 inserted
# row: 15 inserted
# row: 18 inserted
# row: 19 inserted
# row: 22 inserted
# row: 24 inserted
# row: 28 inserted
# row: 32 inserted
# row: 44 inserted
# row: 45 inserted
# row: 47 inserted
# row: 48 inserted
# row: 49 inserted
# row: 51 inserted
# row: 52 inserted
# row: 53 inserted
# row: 55 inserted
# row: 56 inserted
# row: 57 inserted
# row: 64 inserted
# row: 66 inserted
# row: 67 inserted
# row: 68 inserted
# row: 70 inserted
# row: 73 inserted
# row: 75 inserted
# row: 77 inserted
# row: 79 inserted
# row: 81 inserted
# row: 84 inserted
# row: 87 inserted
# row: 89 inserted
# row: 92 inserted
# row: 95 inserted
# row: 102 inserted
# row: 106 inserted
# row: 108 inserted
# row: 109 inserted
# row: 113 inserted
# row: 114 inserted
# row: 116 inserted
# row: 120 inserted
# row: 122 inserted
# row: 125 inserted
# row: 128 inserted
# row: 129 inserted
# row: 131 inserted
# row: 133 inserted
# row: 134 inserted
# row: 135 inserted
# row: 136 inserted
# row: 140 inserted
# row: 141 inserted
# row: 142 inserted
# row: 144 inserted
# row: 148 inserted
# row: 151 inserted
# row: 152 inserted
# row: 154 inserted
# row: 157 inserted
# row: 166 inserted
# row: 168 inserted
# row: 169 inserted
# row: 171 inserted
# row: 172 inserted
# row: 176 inserted
# row: 178 inserted
# row: 179 inserted
# row: 184 inserted
# row: 185 inserted
# row: 186 inserted
# row: 187 inserted
# row: 190 inserted
# row: 192 inserted
# row: 199 inserted
# row: 200 inserted
# row: 201 inserted
# row: 203 inserted
# row: 205 inserted
# row: 207 inserted
# row: 209 inserted
# row: 212 inserted
# row: 214 inserted
# row: 215 inserted
# row: 216 inserted
# row: 217 inserted
# row: 218 inserted
# row: 219 inserted
# row: 220 inserted
# row: 225 inserted
# row: 228 inserted
# row: 230 inserted
# row: 234 inserted
# row: 239 inserted
# row: 240 inserted
# row: 248 inserted
# row: 249 inserted
# row: 251 inserted
# row: 253 inserted
# row: 257 inserted
# row: 265 inserted
# row: 275 inserted
# row: 277 inserted
# row: 279 inserted
# row: 281 inserted
# row: 282 inserted
# row: 289 inserted
# row: 290 inserted
# row: 292 inserted
# row: 296 inserted
# row: 297 inserted
#
#
#  112 ROWS INSERTED SUCCESSFULLY INTO tweets_db.META

# %% [markdown]
# ### Extract data from the MongoDB database

# %%
# Retrieve data from MongoDB
data_from_mongodb = get_tweets_from_db(uri=URI, db_name=DB_NAME, collection_name="META")

# Create DataFrame from retrieved data
df_meta_tweets_ = pd.DataFrame(data_from_mongodb)

df_meta_tweets_
# Out:
#                           _id                  date  \
# 0    65f0bf79cdbba6c28e28124b  2024-03-12T20:39:18Z
# 1    65f0bf7acdbba6c28e28124d  2024-03-12T20:35:09Z
# 2    65f0bf7acdbba6c28e28124f  2024-03-12T19:46:15Z
# 3    65f0bf7bcdbba6c28e281251  2024-03-12T19:37:31Z
# 4    65f0bf7ccdbba6c28e281253  2024-03-12T19:36:29Z
# ..                        ...                   ...
# 107  65f0bfc2cdbba6c28e281321  2024-03-12T00:23:08Z
# 108  65f0bfc3cdbba6c28e281323  2024-03-12T00:20:07Z
# 109  65f0bfc4cdbba6c28e281325  2024-03-12T00:08:53Z
# 110  65f0bfc4cdbba6c28e281327  2024-03-11T23:49:38Z
# 111  65f0bfc5cdbba6c28e281329  2024-03-11T23:49:28Z
#
#                                                content true_sentiment
# 0    $SPY $NVDA $META $ORCL Only sad BEARS on here ...        bullish
# 1    $META 510 Tomorrow Bears Was that over the top...        bullish
# 2    $PSTG $NTAP $META that’s a big hit to PSTG pro...        bearish
# 3    $ATNF looks primed for a big Squeeze 🔥  \n \nW...        bullish
# 4                     $META it’s over. Thx for playing        bearish
# ..                                                 ...            ...
# 107          $META &quot;the enemy of the people&quot;        bearish
# 108  $META we don’t need any one to tell us who is ...        bullish
# 109  $META I see downtrend forming but the oversold...        bullish
# 110        $META so so OVERSOLD Will be UP like a yoyo        bullish
# 111  $META Trump reminds of that movie idiocracy. A...        bullish
#
# [112 rows x 4 columns]
