# %% [markdown]
# # Sentiment Analysis of Stock Twits with Multi Layer Perceptron

# %% [markdown]
# ### Import libs

# %%
#### NLP LIBS ###
import nltk
import numpy as np
import pandas as pd

from sklearn.neural_network import MLPClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

### Import utils function ###
from utils import get_tweets_from_db, eval_model, URI, DB_NAME
from cleaning_utils import full_preprocess, get_grams

# %% [markdown]
# ### Get Tweets from MongoDB database (`db_tweets.META`)

# %%
# Retrieve data from MongoDB
data_from_mongodb = get_tweets_from_db(uri=URI, db_name=DB_NAME, collection_name="AAPL")

# Create DataFrame from retrieved data
df_apple_tweets = pd.DataFrame(data_from_mongodb)

df_apple_tweets
# Out:
#                           _id                  date  \
# 0    662691526f6491024e22dd9f  2024-04-22T16:30:04Z
# 1    662691536f6491024e22dda1  2024-04-22T16:27:30Z
# 2    662691536f6491024e22dda3  2024-04-22T16:26:43Z
# 3    662691546f6491024e22dda5  2024-04-22T16:26:06Z
# 4    662691556f6491024e22dda7  2024-04-22T16:24:16Z
# ..                        ...                   ...
# 137  662691d86f6491024e22deb1  2024-04-22T15:12:24Z
# 138  662691d86f6491024e22deb3  2024-04-22T15:12:07Z
# 139  662691e26f6491024e22deb5  2024-04-22T16:30:04Z
# 140  662691e46f6491024e22deb7  2024-04-22T16:27:30Z
# 141  662691e56f6491024e22deb9  2024-04-22T16:26:43Z
#
#                                                content true_sentiment
# 0                $AAPL nice dip quickies $$$$$$$$$$$$$           None
# 1                             $AAPL fucking sweatshops        bearish
# 2    $AAPL cnbc guy says sees another 5% down bit h...           None
# 3    $AAPL look for a move to the downside in the s...        bullish
# 4    Hey $AAPL $CMCSA &amp; $GOOG you can have my $...           None
# ..                                                 ...            ...
# 137                                          $AAPL 140        bearish
# 138  $AAPL Y&#39;all were supposed to sell at 200. ...        bullish
# 139              $AAPL nice dip quickies $$$$$$$$$$$$$           None
# 140                           $AAPL fucking sweatshops        bearish
# 141  $AAPL cnbc guy says sees another 5% down bit h...           None
#
# [142 rows x 4 columns]

# %% [markdown]
# ## Data preprocessing
#
# - replace the hashtags
# - remove stopwords and useless punctuation

# %%
df_apple_tweets["cleaned_content"] = df_apple_tweets["content"].apply(full_preprocess)
df_apple_tweets
# Out:
#                           _id                  date  \
# 0    662691526f6491024e22dd9f  2024-04-22T16:30:04Z
# 1    662691536f6491024e22dda1  2024-04-22T16:27:30Z
# 2    662691536f6491024e22dda3  2024-04-22T16:26:43Z
# 3    662691546f6491024e22dda5  2024-04-22T16:26:06Z
# 4    662691556f6491024e22dda7  2024-04-22T16:24:16Z
# ..                        ...                   ...
# 137  662691d86f6491024e22deb1  2024-04-22T15:12:24Z
# 138  662691d86f6491024e22deb3  2024-04-22T15:12:07Z
# 139  662691e26f6491024e22deb5  2024-04-22T16:30:04Z
# 140  662691e46f6491024e22deb7  2024-04-22T16:27:30Z
# 141  662691e56f6491024e22deb9  2024-04-22T16:26:43Z
#
#                                                content true_sentiment  \
# 0                $AAPL nice dip quickies $$$$$$$$$$$$$           None
# 1                             $AAPL fucking sweatshops        bearish
# 2    $AAPL cnbc guy says sees another 5% down bit h...           None
# 3    $AAPL look for a move to the downside in the s...        bullish
# 4    Hey $AAPL $CMCSA &amp; $GOOG you can have my $...           None
# ..                                                 ...            ...
# 137                                          $AAPL 140        bearish
# 138  $AAPL Y&#39;all were supposed to sell at 200. ...        bullish
# 139              $AAPL nice dip quickies $$$$$$$$$$$$$           None
# 140                           $AAPL fucking sweatshops        bearish
# 141  $AAPL cnbc guy says sees another 5% down bit h...           None
#
#                                        cleaned_content
# 0                              cashtag nice dip quicki
# 1                               cashtag fuck sweatshop
# 2    cashtag cnbc guy say see anoth 5 % bit ha buy ...
# 3    cashtag look move downsid short term howev exp...
# 4       hey cashtag cashtag cashtag cashtag cash stock
# ..                                                 ...
# 137                                        cashtag 140
# 138  cashtag suppos sell 200 buy mfkin dip earn bad...
# 139                            cashtag nice dip quicki
# 140                             cashtag fuck sweatshop
# 141  cashtag cnbc guy say see anoth 5 % bit ha buy ...
#
# [142 rows x 5 columns]

# %%
df_apple_tweets = df_apple_tweets[df_apple_tweets['true_sentiment'].isin(['bullish', 'bearish'])]

# %%
X = df_apple_tweets[df_apple_tweets['true_sentiment'].isin(['bullish', 'bearish'])]["cleaned_content"]

# Select features
X = df_apple_tweets["cleaned_content"]

# Select the labels
y = df_apple_tweets['true_sentiment']

# %% [markdown]
# ### Building Bag of Words (BoW)
#
# To do so, we convert text data into numerical features using `CountVectorizer`
#
# We use *unigram* and *bigram* as text features so we set the parameter `ngram_range=(2,2)`
#
# We set the parameter `min_df` because we want to impose a minimum word frequency of 0.0001% (or 25 occurrences) to remove very infrequent words and reduce computation time for GridSearchCV
#
# Hence, when building the vocabulary ignore terms that have a document frequency strictly lower than the given threshold. This value is also called cut-off in the literature

# %%
# Convert text data into numerical feature
X_vectorized = get_grams(X, ngrams=(2,2), min_frequency=0.0001)

# %% [markdown]
# ## Train test split data

# %%
# Split the dataframe
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Initialize the MLP

# %%
mlp_classifier = MLPClassifier(random_state=42)

# %% [markdown]
# #### Define the hyperameters for the grid search CV

# %%
# Step 5: Define hyperparameters grid
param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (150,)],
    'activation': ['logistic'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.001, 0.01]
}

# %% [markdown]
# ### Apply the grid search CV

# %%
# Step 6: Initialize GridSearchCV
grid_search = GridSearchCV(estimator=mlp_classifier, param_grid=param_grid, cv=3, scoring='accuracy')

# Step 7: Perform GridSearchCV
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\humic\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# GridSearchCV(cv=3, estimator=MLPClassifier(random_state=42),
#              param_grid={'activation': ['logistic'], 'alpha': [0.001, 0.01],
#                          'hidden_layer_sizes': [(50,), (100,), (150,)],
#                          'solver': ['adam', 'sgd']},
#              scoring='accuracy')

# %% [markdown]
# ### Get the best parameters and best score

# %%
best_params = grid_search.best_params_
best_score = grid_search.best_score_
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Best Parameters: {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (50,), 'solver': 'adam'}
# Best Score: 0.8799019607843137

# %% [markdown]
# ### Get the predictions (forward path)

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
y_pred
# Out:
# array(['bullish', 'bearish', 'bearish', 'bullish', 'bullish', 'bullish',
#        'bullish', 'bullish', 'bullish', 'bearish', 'bullish', 'bullish',
#        'bullish'], dtype='<U7')

# %% [markdown]
# #### Post-Processing: Compute the predicted label
# * `bullish`
# * `bearish`

# %% [markdown]
# ### Model Evaluation
#
# To evaluate the model performance prediction we compute the confusion matrix and the classification report

# %%
eval_model(pd.DataFrame(y_test), pd.DataFrame(y_pred))
# Out:
# ######## Classification Report ########
#
#               precision    recall  f1-score   support
#
#      bearish       1.00      1.00      1.00         3
#      bullish       1.00      1.00      1.00        10
#
#     accuracy                           1.00        13
#    macro avg       1.00      1.00      1.00        13
# weighted avg       1.00      1.00      1.00        13
#
# ######## Accuracy Score ########
# 1.0

# %% [markdown]
# #### Store the predicted sentiment into a new MongoDB Collection

# %%
## TO DO
